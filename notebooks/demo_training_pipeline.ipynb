# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # ALIAS Training Pipeline Demo
#
# This notebook demonstrates the complete workflow from loading scRNA-seq data to training a sentence-transformer model.
#
# ## Pipeline Overview
#
# 1. **Load Data**: Load `.h5ad` file containing scRNA-seq data
# 2. **Configure**: Set up configurations for data processing
# 3. **Build Datasets**: Convert scRNA data to text-based datasets
# 4. **Generate Triplets**: Create training pairs for contrastive learning
# 5. **Train Model**: Fine-tune a sentence transformer model
#
# ## Prerequisites
#
# **Option A:** Place your own `.h5ad` file at `data/demo.h5ad`
# **Option B:** Use scanpy's built-in PBMC dataset (no file needed!) 👈 **Recommended for demo**

# %%
# Imports
import scanpy as sc
import numpy as np
from pathlib import Path

# ALIAS imports
from alias.data import (
    DatascRNAConfig,
    TripletGenerationConfig,
    build_datasets,
    build_triplets
)
from alias.model import TrainingSTConfig, train_model

# %% [markdown]
# ## Step 1: Load scRNA-seq Data
#
# You have two options:
# - **Option A**: Load your own `.h5ad` file
# - **Option B**: Use scanpy's PBMC 3k dataset (2,638 cells, 8 cell types) ← **Easiest!**
#
# Here we load the PBMC 3k dataset in the raw and processed version, for transferring the cell type labels to the raw dataset.
#
# The data needs:
# - Cell type annotations in `obs`
# - Gene expression matrix in `X`
# - Gene names in `var`

# %%
# Option B: Load PBMC 3k datasets
adata_labels = sc.datasets.pbmc3k_processed()
adata = sc.datasets.pbmc3k()

# We keep only cells in adata that are also in adata_labels
common_cells = adata.obs_names.intersection(adata_labels.obs_names)
adata_filtered = adata[common_cells].copy()  # subset adata

# We assign the cell type labels to the raw adata
adata_filtered.obs['louvain'] = adata_labels.obs['louvain'].reindex(common_cells).values
adata = adata_filtered.copy()
label_key = 'louvain'

print(f"\n✓ Loaded AnnData: {adata.shape[0]} cells x {adata.shape[1]} genes")
print(f"Available obs columns: {list(adata.obs.columns)}")
print(f"\nCell type distribution:")
print(adata.obs[label_key].value_counts())
# Out:
# ✓ Loaded AnnData: 2638 cells x 32738 genes
# Available obs columns: ['louvain']
#
# Cell type distribution:
# louvain
# CD4 T cells          1144
# CD14+ Monocytes       480
# B cells               342
# CD8 T cells           316
# NK cells              154
# FCGR3A+ Monocytes     150
# Dendritic cells        37
# Megakaryocytes         15
# Name: count, dtype: int64

# %% [markdown]
# ## Step 2: Configure Data Processing
#
# Set up configuration for scRNA dataset generation:
# - `annotation_column`: Column in `obs` containing cell type labels
# - `preprocessing`: Whether to run scanpy preprocessing
# - `test_size`: Fraction of data to use for testing
# - `cs_length`: Length of cell sentences (number of genes)

# %%
# Create scRNA data configuration
scrna_config = DatascRNAConfig(
    annotation_column=label_key,  # Change this to match your data
    preprocessing=True,  # Set to True if data needs preprocessing
    test_size=0.1,  # 10% for testing
    cs_length=[50],  # Create cell sentences with 50 genes
    highly_variable_genes=True,
    semantic=True,  # Use semantic templates
    random_state=42
)

print("scRNA Configuration:")
print(f"  - Annotation column: {scrna_config.annotation_column}")
print(f"  - Test size: {scrna_config.test_size}")
print(f"  - Cell sentence lengths: {scrna_config.cs_length}")
# Out:
# scRNA Configuration:
#   - Annotation column: louvain
#   - Test size: 0.1
#   - Cell sentence lengths: [50]

# %% [markdown]
# ## Step 3: Build Datasets
#
# Convert the AnnData object into HuggingFace Dataset format.
# This creates "cell sentences" - text representations of gene expression.

# %%
# Build datasets from AnnData
dataset_dict, adata_test = build_datasets(
    adata=adata,
    datasets=['scrna'],  # Only scRNA for this demo
    scrna_config=scrna_config
)

print(f"\nDatasets created:")
for dataset_name, splits in dataset_dict.items():
    print(f"\n{dataset_name}:")
    for split_name, split_data in splits.items():
        print(f"  - {split_name}: {len(split_data)} samples")
        if len(split_data) > 0:
            print(f"    Features: {list(split_data.features.keys())}")

# Preview first example
print("\n" + "="*50)
print("Example cell sentence:")
print("="*50)
example = dataset_dict['scrna']['data'][0]
print(f"Sentence: {example['sentence1'][:100]}...")
print(f"Label: {example['label']}")
# Out:
# Preprocessing AnnData object...
# Filtering cells with fewer than 100 expressed genes...
# Filtering cells with a percentage of mitochondrial genes expressed over 15...
# Filtering genes expressed in fewer than 5 cells...
# Analyzing cell type sizes...
# Initial number of celtypes: 8
# Batches with fewer than 5 cells: 0
# Filtering small batches...
# Normalizing total counts per cell...
# Performing log transformation...
# Identifying 3000 highly variable genes...
# Subsetting to highly variable genes...
# Preprocessing complete. Your AnnData object is ready for further analysis.
# AnnData object with n_obs × n_vars = 2638 × 3000
#     obs: 'louvain', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'n_genes'
#     var: 'gene_ids', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'normalized', 'log1p', 'logged', 'hvg'
#     layers: 'counts'
# Building dataset: 100%|██████████| 2638/2638 [00:00<00:00, 37231.39it/s]
# Map: 100%|██████████| 2374/2374 [00:00<00:00, 22653.14 examples/s]
# Map: 100%|██████████| 264/264 [00:00<00:00, 22204.99 examples/s]
# Datasets created:
#
# scrna:
#   - data: 2374 samples
#     Features: ['index', 'gene_list', 'louvain', 'label', 'sentence1']
#   - test: 264 samples
#     Features: ['index', 'gene_list', 'louvain', 'label', 'sentence1']
#
# ==================================================
# Example cell sentence:
# ==================================================
# Sentence: Cells expressing B2M, MALAT1, ACTB, SNRPE, HLA-A, HLA-C, EEF1D, CCL5, HLA-B, KLF6, TPT1, PFN1, H3F3B...
# Label: CD8 T cells

# %% [markdown]
# ## Step 4: Generate Triplets
#
# Create training triplets for contrastive learning:
# - Anchor: Original cell sentence
# - Positive: Similar cell (same cell type)
# - Negative: Dissimilar cell (different cell type)

# %%
# Configure triplet generation
triplet_config = TripletGenerationConfig(
    annotation_column=label_key,
    loss='MNR',  # MultipleNegativesRanking loss
    eval_split=0.1,  # 10% for evaluation
    random_negative_mining=False,  # Set True for random negative mining (faster, lower performance)
    hard_negative_mining=True,  # Set True for hard negative mining (slower)
    testrun=False,
    seed=42
)

print("Triplet Configuration:")
print(f"  - Loss type: {triplet_config.loss}")
print(f"  - Eval split: {triplet_config.eval_split}")
print(f"  - Random negative mining: {triplet_config.random_negative_mining}")
print(f"  - Hard negative mining: {triplet_config.hard_negative_mining}")
# Out:
# Triplet Configuration:
#   - Loss type: MNR
#   - Eval split: 0.1
#   - Random negative mining: False
#   - Hard negative mining: True

# %%
# Generate triplets
triplet_dict = build_triplets(
    dataset_dict=dataset_dict,
    triplet_config=triplet_config
)

print(f"\nTriplets created:")
for dataset_name, splits in triplet_dict.items():
    print(f"\n{dataset_name}:")
    for split_name, split_data in splits.items():
        print(f"  - {split_name}: {len(split_data)} triplets")
        if len(split_data) > 0:
            print(f"    Features: {list(split_data.features.keys())}")

# Preview a triplet
print("\n" + "="*50)
print("Example triplet:")
print("="*50)
example_triplet = triplet_dict['scrna']['train_MNR_hnm'][0]
print(f"Anchor: {example_triplet['sentence1'][:80]}...")
print(f"Positive: {example_triplet['sentence2'][:80]}...")
print(f"Negative: {example_triplet['negative'][:80]}...")
# Out:
# Building triplets for scrna...
# Generating semantic training pairs for training with MultipleNgeativesRanking loss...
# Processing scrna data...
# Generating pairs by label: 100%|██████████| 8/8 [00:00<00:00, 581.52it/s]
# ✅ Created 11870 total semantic pairs.
# Loading public HuggingFace model 'neuml/pubmedbert-base-embeddings'.
# Mining hard negatives...:   0%|          | 0/2 [00:00<?, ?it/s]
# Found an average of 4.212 positives per query.
# Batches: 100%|██████████| 19/19 [00:09<00:00,  2.07it/s]
# Batches: 100%|██████████| 19/19 [00:10<00:00,  1.89it/s]
# Assigning label_indices: 100%|██████████| 8/8 [00:00<00:00, 93990.01it/s]
# Mining hard negatives...:  50%|█████     | 1/2 [00:26<00:26, 26.54s/it]
# Found an average of 1.361 positives per query.
# Batches: 100%|██████████| 11/11 [00:05<00:00,  2.08it/s]
# Batches: 100%|██████████| 11/11 [00:05<00:00,  1.87it/s]
# Assigning label_indices: 100%|██████████| 8/8 [00:00<00:00, 148470.94it/s]
# Mining hard negatives...: 100%|██████████| 2/2 [00:40<00:00, 20.22s/it]
# Triplets created:
#
# scrna:
#   - train_MNR_hnm: 10662 triplets
#     Features: ['sentence1', 'sentence2', 'negative']
#   - eval_MNR_hnm: 1185 triplets
#     Features: ['sentence1', 'sentence2', 'negative']
#
# ==================================================
# Example triplet:
# ==================================================
# Anchor: A CD4 T cells signature includes: MALAT1, TPT1, B2M, JUNB, ACTB, LTB, HLA-C, HLA...
# Positive: This cell shows high expression of MALAT1, B2M, TPT1, ACTB, EEF1D, HLA-A, JUNB, ...
# Negative: The active genes MALAT1, B2M, N4BP2L1, LYAR, ACTB, TPT1, C1orf162, JUNB, CCL5, D...

# %% [markdown]
# ## Step 5: Configure Training
#
# Set up the model training configuration:
# - Choose base model from HuggingFace
# - Set training hyperparameters
# - Choose where to save the model

# %%
# Training configuration
training_config = TrainingSTConfig(
    model="neuml/pubmedbert-base-embeddings",  # Base model
    loss='MNR',  # Must match triplet_config.loss
    new_model_name="alias_demo_model",
    
    # Training hyperparameters
    batch_size=32,  # Adjust based on your GPU memory
    epochs=2,  # Increase for better results
    warmup_steps=100,
    weight_decay=0.01,
    logging_steps=10,
    
    # Save options
    save_to_local=True,
    save_to_hf=False,  # Set True to push to HuggingFace Hub
    
    # Hardware
    fp16=False,  # Set True if you have a GPU with fp16 support
    
    # Testing
    testrun=False,  # Set True for quick test
    seed=73
)

print("Training Configuration:")
print(f"  - Base model: {training_config.model}")
print(f"  - Loss: {training_config.loss}")
print(f"  - Batch size: {training_config.batch_size}")
print(f"  - Epochs: {training_config.epochs}")
print(f"  - Save locally: {training_config.save_to_local}")
print(f"  - Save to HF: {training_config.save_to_hf}")
# Out:
# Training Configuration:
#   - Base model: neuml/pubmedbert-base-embeddings
#   - Loss: MNR
#   - Batch size: 32
#   - Epochs: 2
#   - Save locally: True
#   - Save to HF: False

# %% [markdown]
# ## Step 6: Train the Model
#
# ⚠️ **Note**: Training may take a while depending on:
# - Dataset size
# - Number of epochs
# - Available hardware (GPU/CPU)
#
# The model will be saved to `/models/` directory.
#
# If you do not want to train your own model, you can skip to Step 7, where you load the model trained on the PBMC 3k dataset frmom hugginface.

# %%
# Train the model 
trained_model = train_model(
    dataset_dict=triplet_dict,
    datasets='scrna',
    train_config=training_config
)

print("\n" + "="*50)
print("Training completed!")
print("="*50)
# Out:
# Loading public HuggingFace model 'neuml/pubmedbert-base-embeddings'.
# Loaded model neuml/pubmedbert-base-embeddings on mps
# MultipleNegativesRanking Loss loaded!
# Starting fine-tuning on scrna
# /Users/mariakrissmer/Desktop/Repositories/alias/.venv_alias/lib/python3.12/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
#       <progress value='668' max='668' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [668/668 16:48, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# /Users/mariakrissmer/Desktop/Repositories/alias/.venv_alias/lib/python3.12/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Training completed.
#  Model saved to /Users/mariakrissmer/Desktop/Repositories/alias/notebooks/models/alias_demo_model
#
# ==================================================
# Training completed!
# ==================================================

# %% [markdown]
# ## Step 7: Verify the Trained Model
#
# Generate embeddings of our test dataset with trained as well as base model.

# %%
# Load embedding function
from alias.evaluation import generate_embeddings, GenEmbeddingsConfig

# The model is saved in out/models/
model_path = Path("models") / training_config.new_model_name
print(f"Loading model from: {model_path}")

# Embedding configuration
embedding_config = GenEmbeddingsConfig(
    embedding_models=["neuml/pubmedbert-base-embeddings", str(model_path)],  # use "mariakrissmer/alias_demo_model" if you did not run the training yourself
    model_type="sentence_transformer",
    batch_size=64,
    additional_data=None, 
    output_dir="embeddings",
    max_cells=5000,
    annotation_column=label_key
)

# Test embedding generation
embeddings_dict = generate_embeddings(
    evaluation_dict= dataset_dict,
    embedding_config=embedding_config,
)

print("\n" + "="*50)
print("Embeddings generated!")
print("="*50)
# Out:
# Loading model from: models/alias_demo_model
# Embedding Models:   0%|          | 0/2 [00:00<?, ?it/s]
#  Generating embeddings with model: neuml/pubmedbert-base-embeddings
# Loading public HuggingFace model 'neuml/pubmedbert-base-embeddings'.
# Encoding df_cells (264 samples)
# Batches: 100%|██████████| 5/5 [00:00<00:00,  7.11it/s]
# Encoding df_genes (1125 samples)
# Batches: 100%|██████████| 18/18 [00:00<00:00, 89.75it/s]
# Encoding df_celltypes (7 samples)
# Batches: 100%|██████████| 1/1 [00:00<00:00, 114.53it/s]
# Encoding df_labels (7 samples)
# Batches: 100%|██████████| 1/1 [00:00<00:00, 138.49it/s]
# Embedding Models:  50%|█████     | 1/2 [00:04<00:04,  4.98s/it]
#  Generating embeddings with model: models/alias_demo_model
# Loading local model from: models/alias_demo_model
# Encoding df_cells (264 samples)
# Batches: 100%|██████████| 5/5 [00:00<00:00,  7.21it/s]
# Encoding df_genes (1125 samples)
# Batches: 100%|██████████| 18/18 [00:00<00:00, 88.81it/s]
# Encoding df_celltypes (7 samples)
# Batches: 100%|██████████| 1/1 [00:00<00:00, 132.94it/s]
# Encoding df_labels (7 samples)
# Batches: 100%|██████████| 1/1 [00:00<00:00, 123.09it/s]
# Embedding Models: 100%|██████████| 2/2 [00:06<00:00,  3.15s/it]
# ==================================================
# Embeddings generated!
# ==================================================

# %%
# Load umap plotting function for visualization of model embeddings
from alias.evaluation import umap_plots, EvaluationConfig

evaluation_config = EvaluationConfig(n_neighbors=20)

embeddings_dict = umap_plots(
    embeddings_dict=embeddings_dict,
    annotation_column=label_key,
    output_dir="figures",
    evaluation_config=evaluation_config
)
# Out:
# Evaluating model: pubmedbertbaseembeddings
# Processing dataset: scrna
# Computing UMAP for 271 embeddings...
# /Users/mariakrissmer/Desktop/Repositories/alias/.venv_alias/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /Users/mariakrissmer/Desktop/Repositories/alias/.venv_alias/lib/python3.12/site-packages/pandas/io/parquet.py:191: UserWarning: The DataFrame has column names of mixed type. They will be converted to strings and not roundtrip correctly.
#   table = self.api.Table.from_pandas(df, **from_pandas_kwargs)
# ✅ Saved UMAP coords and plots for pubmedbertbaseembeddings / scrna
#
# Evaluating model: alias_demo_model
# Processing dataset: scrna
# Computing UMAP for 271 embeddings...
# /Users/mariakrissmer/Desktop/Repositories/alias/.venv_alias/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /Users/mariakrissmer/Desktop/Repositories/alias/.venv_alias/lib/python3.12/site-packages/pandas/io/parquet.py:191: UserWarning: The DataFrame has column names of mixed type. They will be converted to strings and not roundtrip correctly.
#   table = self.api.Table.from_pandas(df, **from_pandas_kwargs)
# ✅ Saved UMAP coords and plots for alias_demo_model / scrna

# %%
# As the plots are automatically saved in a figures subfolder, 
# we load them here for display:

from IPython.display import SVG, display

# Base model embeddings
display(SVG("figures/pubmedbertbaseembeddings/scrna/cells_with_celltype_labels.svg"))

# %%
# Trained model embeddings
display(SVG("figures/alias_demo_model/scrna/cells_with_celltype_labels.svg"))

# %% [markdown]
# ## Summary
#
# You've successfully:
# 1. ✅ Loaded scRNA-seq data from `.h5ad` file
# 2. ✅ Converted cells to text-based "cell sentences"
# 3. ✅ Generated training triplets for contrastive learning
# 4. ✅ Fine-tuned a sentence transformer model
# 5. ✅ Verified the model can generate embeddings
#
# ## Next Steps
#
# - Evaluate the model on downstream tasks
# - Integrate with NCBI literature data for multi-modal training
# - Experiment with different hyperparameters
